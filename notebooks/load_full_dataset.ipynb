# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls /content/gdrive/MyDrive/training/
# Out:
# load_full_dataset.ipynb  testing		    training
# sample_submission.csv	 train_image_level.csv.zip  train_study_level.csv

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-92582539-fcd6-46e2-9669-4c14508be67d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-92582539-fcd6-46e2-9669-4c14508be67d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"davybayet","key":"dd73ffa5d357468023ffb2d3534c80f5"}'}

# %%
pip install pydicom
# Out:
# ...
#      |████████████████████████████████| 1.9MB 4.1MB/s
# ...

# %%
pip install opencv-python

# %%
# !pip install kaggle

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import tensorflow as tf
from shutil import copyfile
import os
import cv2
import pydicom
from pydicom import dcmread
from pydicom.data import get_testdata_file

# %%
# !pip install -q kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !ls ~/.kaggle
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
# kaggle.json

# %%
import os
os.chdir('/content/gdrive/MyDrive/ColabNotebooks/kaggle/fulldataset')  
# !mkdir training 
# !mkdir testing

# %%
# !unzip -q train.zip -d training/  #unzip data in training/
# !unzip -q test.zip -d testing/  #unzip data in testing/

# %%
main_path = "/content/gdrive/MyDrive/testing"
#df = pd.read_csv()
os.listdir(main_path)
# Out:
# ['00188a671292',
#  '004bd59708be',
#  '00508faccd39',
#  '006486aa80b2',
#  '00655178fdfc',
#  '00a81e8f1051',
#  '00be7de16711',
#  '00c7a3928f0f',
#  '00d63957bc3a',
#  '0107f2d291d6',
#  '0154653179fa',
#  '015f89ec55ea',
#  '0241bc13eac6',
#  '025bfc117ff8',
#  '028abd3504b6',
#  '02ee3a9820eb',
#  '0321bb7f84b5',
#  '03e0a59d9b8a',
#  '03fc9ec0dba8',
#  '045783dbe7d1',
#  '04c42f33c006',
#  '04c4e92d40b8',
#  '04d0f88f790a',
#  '059007b73d82',
#  '05ce6249b5c0',
#  '05f22f0c2412',
#  '061969abb8a5',
#  '063ee1363644',
#  '06d315ac12ff',
#  '06fa49182629',
#  '070d030a9ff7',
#  '07467db0a5ae',
#  '074763143b55',
#  '07bac22f0a34',
#  '080ea6634d62',
#  '0816f9d3875e',
#  '0838c0a2c424',
#  '0843b8e9ca34',
#  '0847751da0f7',
#  '08cc9af3edf8',
#  '096601e1340d',
#  '098be79259d5',
#  '0992f862466e',
#  '0a50336ef885',
#  '0ac42f524362',
#  '0b1d3c1abed3',
#  '0b1f60821d8f',
#  '0b55f8263527',
#  '0b6af2d5fa06',
#  '0ba4b75a0784',
#  '0bc43d526b5d',
#  '0bdd39af9529',
# ...

# %%
destination_path = "/content/gdrive/MyDrive/fulltesting"

# %%
list_of_folders = os.listdir(main_path)
list_of_folders
# Out:
# ['00188a671292',
#  '004bd59708be',
#  '00508faccd39',
#  '006486aa80b2',
#  '00655178fdfc',
#  '00a81e8f1051',
#  '00be7de16711',
#  '00c7a3928f0f',
#  '00d63957bc3a',
#  '0107f2d291d6',
#  '0154653179fa',
#  '015f89ec55ea',
#  '0241bc13eac6',
#  '025bfc117ff8',
#  '028abd3504b6',
#  '02ee3a9820eb',
#  '0321bb7f84b5',
#  '03e0a59d9b8a',
#  '03fc9ec0dba8',
#  '045783dbe7d1',
#  '04c42f33c006',
#  '04c4e92d40b8',
#  '04d0f88f790a',
#  '059007b73d82',
#  '05ce6249b5c0',
#  '05f22f0c2412',
#  '061969abb8a5',
#  '063ee1363644',
#  '06d315ac12ff',
#  '06fa49182629',
#  '070d030a9ff7',
#  '07467db0a5ae',
#  '074763143b55',
#  '07bac22f0a34',
#  '080ea6634d62',
#  '0816f9d3875e',
#  '0838c0a2c424',
#  '0843b8e9ca34',
#  '0847751da0f7',
#  '08cc9af3edf8',
#  '096601e1340d',
#  '098be79259d5',
#  '0992f862466e',
#  '0a50336ef885',
#  '0ac42f524362',
#  '0b1d3c1abed3',
#  '0b1f60821d8f',
#  '0b55f8263527',
#  '0b6af2d5fa06',
#  '0ba4b75a0784',
#  '0bc43d526b5d',
#  '0bdd39af9529',
# ...

# %%
for i in list_of_folders:
  list2 = os.listdir(main_path + "/" + i)
  if len(list2)!=0:
    for j in list2:
      list3 = os.listdir(main_path + "/" + i+"/" + j)
      for t in list3:
        if t.find(".dcm")!=-1:
          copyfile(main_path + "/" + i+"/" + j+ "/" + t, destination_path + "/"+t)

# %%
images_list_test = os.listdir(destination_path)
images_list_test
# Out:
# ['3dcdfc352a06.dcm',
#  'c39146cbda47.dcm',
#  '951211f8e1bb.dcm',
#  '5e0e7acd9c7d.dcm',
#  '5b8ee5baa1d5.dcm',
#  'ced40f593496.dcm',
#  'cea591e99b8a.dcm',
#  'f6ba3df9a8be.dcm',
#  'dbae9b9b9500.dcm',
#  '695e2c6dede4.dcm',
#  '51635cbfbe18.dcm',
#  'af7d1bd1d629.dcm',
#  '0cccb1eca1fc.dcm',
#  '5af15b21333b.dcm',
#  'fec0249d70e4.dcm',
#  'ad98af65ad2a.dcm',
#  '53b4af5b74d7.dcm',
#  '26fa9834387e.dcm',
#  '6c42a41a6c6e.dcm',
#  'e92b08b5a77c.dcm',
#  '961a766a5511.dcm',
#  '520a1a7b039b.dcm',
#  '927bd54fd2dd.dcm',
#  'ea39ebfacca2.dcm',
#  'e226747a2d76.dcm',
#  '0718c860f2ee.dcm',
#  'ac238e67fdc5.dcm',
#  '1c5aa8c405c7.dcm',
#  '895701fa488e.dcm',
#  '1d674718db40.dcm',
#  '19e9733ee506.dcm',
#  '8180af690aef.dcm',
#  '94cb9518e355.dcm',
#  '4c4737c3e3f8.dcm',
#  'f1b66ff8f4eb.dcm',
#  '29c992128fbd.dcm',
#  '572d5c14fc66.dcm',
#  'fb073252b364.dcm',
#  '82589da89e95.dcm',
#  '5020cd97beb8.dcm',
#  'ad3e33d5f844.dcm',
#  '5472531dd991.dcm',
#  '7bba27555fe4.dcm',
# ...

# %%
len(images_list)
# Out:
# 6079

# %%
len(images_list_test)
# Out:
# 1223

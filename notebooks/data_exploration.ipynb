# %%
import matplotlib.pyplot as plt
import numpy as np
#import os
from PIL import Image
#import tensorflow as tf
#import  cv2
from pydicom import dcmread
#from pydicom.data import get_testdata_file

# %%
ds = dcmread('f6293b1c49e2.dcm')
print(ds)

plt.imshow(ds.pixel_array,cmap=plt.cm.gray)
plt.show()
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0002) Media Storage SOP Class UID         UI: Digital X-Ray Image Storage - For Presentation
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.840.113654.2.70.1.33420481611725494636567756883653612791
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'PRIMARY']
# (0008, 0016) SOP Class UID                       UI: 71228e4340de
# (0008, 0018) SOP Instance UID                    UI: f6293b1c49e2
# (0008, 0020) Study Date                          DA: '1f56c43c7013'
# (0008, 0030) Study Time                          TM: '294ed222fa5d'
# (0008, 0050) Accession Number                    SH: '1be0f8c7b013'
# (0008, 0060) Modality                            CS: 'DX'
# (0009, 0010) Private Creator                     LO: 'GEIIS'
# (0010, 0010) Patient's Name                      PN: '1417afaebcd5'
# (0010, 0020) Patient ID                          LO: 'f942cf0989ff'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0012, 0063) De-identification Method            LO: 'CTP Default:  based on DICOM PS3.15 AnnexE. Details in 0012,0064'
# (0012, 0064)  De-identification Method Code Sequence  6 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '113105'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Clean Descriptors Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113108'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '113109'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Device Identity Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '11'
#    (0008, 0102) Coding Scheme Designator            SH: 'XNAT'
#    (0008, 0103) Coding Scheme Version               SH: '1.0'
#    (0008, 0104) Code Meaning                        LO: 'XNAT DicomEdit 4 Script'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'TORAX'
# (0018, 1164) Imager Pixel Spacing                DS: [0.139, 0.139]
# (0020, 000d) Study Instance UID                  UI: 00292f8c37bd
# (0020, 000e) Series Instance UID                 UI: 73120b4a13cb
# (0020, 0010) Study ID                            SH: '55625fb42f3f'
# (0020, 0011) Series Number                       IS: "1"
# (0020, 0013) Instance Number                     IS: "1"
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 2539
# (0028, 0011) Columns                             US: 3050
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 12
# (0028, 0102) High Bit                            US: 11
# (0028, 0103) Pixel Representation                US: 0
# (0903, 0010) Private Creator                     LO: 'GEIIS PACS'
# (0905, 0010) Private Creator                     LO: 'GEIIS'
# (7fd1, 0010) Private Creator                     LO: 'GEIIS'
# (7fe0, 0010) Pixel Data                          OW: Array of 15487900 elements
